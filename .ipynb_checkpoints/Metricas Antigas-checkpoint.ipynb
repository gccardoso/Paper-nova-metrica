# %% [markdown]
# # Introdução
#
# Este caderno visa aplicar métricas nas imagens da tabela periódica com vários contrastes.

# %%
# Iniciando
exec(open(r"G:\Meu Drive\Desktop\codigos\funcoes_projeto_leite.py").read())

path = r'G:\Meu Drive\Desktop\repositorio de imagens\leite e cafe\leite_recortado_colorido'
local_para_salvar = r'G:\Meu Drive\Desktop'


os.chdir(path)

# Corpo
arquivos_na_pasta =  glob.glob('*.jpg') # modificar caso necessário
arquivos_na_pasta.sort()
listaImagens = []
for file in arquivos_na_pasta:
    print(file)
    listaImagens.append(file)
# Out:
# recorte_leite_00.jpg
# recorte_leite_05.jpg
# recorte_leite_10.jpg
# recorte_leite_15.jpg
# recorte_leite_20.jpg
# recorte_leite_25.jpg
# recorte_leite_30.jpg
# recorte_leite_35.jpg
# recorte_leite_99.jpg

# %%
import pickle

lista_pickle = [listaImagens, testImg, df, df2, df3]
# Saving the objects:
# with open('objs.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
#     pickle.dump(lista_pickle, f)

# Getting back the objects:
# with open('objs.pkl', 'rb') as f:  # Python 3: open(..., 'rb')
#     listaImagens,testImg, df, df2, df3 = pickle.load(f)

# %% [markdown]
# # Definindo as métricas

# %%
exec(open(r"C:\Users\Usuario\OneDrive\githuub\Projeto_Jayter_OCTA\funcoes_projeto_leite.py").read())

# %% [markdown]
# ## Leite

# %% [markdown]
# x, std = media_quadrados(r, iteracoes, tamanho)

# %% [markdown]
# ## HS

# %%
def HS(imagem):
    """
    
    Parametros
    ----------
    imagem: str
        path da imagem
    
    Retorna
    -------
    hs: float
        Valor da métrica HS para a imagem escolhida
    
    """
    
    if type(imagem) == str:
        imagem_GS = imread_gray(imagem)  # 'array (x,y)'
    elif type(imagem) == np.ndarray:
        imagem_GS = imagem # NÃO NECESSARIAMENTE PRETO E BRANCO

          
    count, _ = np.histogram(imagem_GS, bins=256, range=[0, 256])

    histo = count / sum(count)

    cumulative  = np.cumsum(count)
    normcum = (cumulative - min(cumulative))/(max(cumulative)-min(cumulative))
    
    valor1 = np.where(normcum == min(normcum, key=lambda x:abs(x-0.25)))[0][0]
    valor2 = np.where(normcum == min(normcum, key=lambda x:abs(x-0.75)))[0][0]
    
    hs = (valor2 - valor1)/(np.max(imagem_GS)-np.min(imagem_GS))
    return hs

# %% [markdown]
# ## Michelson
# ![image.png](attachment:image.png)

# %%
def michelson(imagem):
    if type(imagem) == str:
        imagem = cv2.imread(imagem,0) 
    elif type(imagem) == np.ndarray:
        imagem = imagem # NÃO NECESSARIAMENTE PRETO E BRANCO
#     imagem = cv2.imread(imagem,0)
    numerador = np.max(imagem) - np.min(imagem)
    denominador = np.max(imagem) + np.min(imagem)
    return numerador/denominador

# %% [markdown]
# ## RMS - Root Mean Square contrast
# ![image.png](attachment:image.png)

# %%
def RMS(imagem):
    if type(imagem) == str:
        imagem = cv2.imread(imagem,0) 
    elif type(imagem) == np.ndarray:
        imagem = imagem # NÃO NECESSARIAMENTE PRETO E BRANCO
#     imagem = cv2.imread(imagem,0)
    imagem = imagem/255
    x,y = imagem.shape
    LM = x * y
    Imed = np.sum(imagem)/LM
    soma1 = (imagem - Imed)**2
    soma2 = np.sum(soma1)
    return np.sqrt(soma2/LM)

# %% [markdown]
# ### Análise de algumas diferentes formas de se ler uma figura

# %% [markdown]
# # Aplicando métricas

# %%
metricas = [HS,michelson, RMS]
lista_HS = []
lista_michelson = []
lista_RMS = []
for file in arquivos_na_pasta:
    lista_HS.append(HS(file))

# %% [markdown]
# Michelson

# %%
for file in arquivos_na_pasta:
    lista_michelson.append(michelson(file))
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in ubyte_scalars
#   """

# %%
for file in arquivos_na_pasta:
    imagem = cv2.imread(file,0)
    numerador = np.max(imagem) - np.min(imagem)
    denominador = np.max(imagem) + np.min(imagem)
    print(file,numerador,denominador,numerador/denominador)
# Out:
# recorte_leite_00.jpg 255 255 1.0
# recorte_leite_05.jpg 132 54 2.4444444
# recorte_leite_10.jpg 69 81 0.8518519
# recorte_leite_15.jpg 44 100 0.44
# recorte_leite_20.jpg 30 110 0.27272728
# recorte_leite_25.jpg 28 120 0.23333333
# recorte_leite_30.jpg 29 123 0.23577236
# recorte_leite_35.jpg
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in ubyte_scalars
#   after removing the cwd from sys.path.
#  34 124 0.27419356
# recorte_leite_99.jpg 53 139 0.38129497

# %% [markdown]
# Não sei pq deu esse erro

# %% [markdown]
# RMS

# %%
for file in arquivos_na_pasta:
    lista_RMS.append(RMS(file))

# %% [markdown]
# Leite

# %%
medias = []
desvios = []
tamanho = 1
iteracoes = 20000
for file in arquivos_na_pasta:
    imagem = cv2.imread(file,0)
    x, std = media_quadrados(imagem, iteracoes, tamanho)
    medias.append(x)
    desvios.append(std)
# Out:
# desvio padrÃ£o =  25.87
# desvio padrÃ£o =  33.39
# desvio padrÃ£o =  42.07
# desvio padrÃ£o =  56.07
# desvio padrÃ£o =  68.70
# desvio padrÃ£o =  71.32
# desvio padrÃ£o =  76.06
# desvio padrÃ£o =  77.66
# desvio padrÃ£o =  52.72

# %% [markdown]
# # Criando DataFrame

# %%
import pandas as pd

# dataframe em preto e branco
concentracao = [0,5,10,15,20,25,30,35,99]
df = pd.DataFrame(
{
    "Concentracao":concentracao,
    "Leite":medias,
    "HS":lista_HS,
    "RMS":lista_RMS,
    "Michelson":lista_michelson,
})

# %%
df
# Out:
#    Concentracao      Leite        HS       RMS  Michelson
# 0             0  252.34800  0.231373  0.227095   1.000000
# 1             5  250.55025  0.210526  0.082456   2.444444
# 2            10  247.86000  0.200000  0.042151   0.851852
# 3            15  242.00775  0.200000  0.024688   0.440000
# 4            20  234.90600  0.161290  0.015062   0.272727
# 5            25  233.18475  0.172414  0.014121   0.233333
# 6            30  229.83150  0.172414  0.013638   0.235772
# 7            35  228.62025  0.147059  0.015040   0.274194
# 8            99  243.58875  0.185185  0.026970   0.381295

# %%
import seaborn as sns
sns.set()

# %%
for coluna in df.columns[1:]:
    plt.figure()
    sns.relplot(x="Concentracao", y=coluna, data=df);

# %%
def quadrados_media_std(imagem, N, tamanho,metrica):
    """
    Aplica uma certa funcao N quadrados de certo tamanho na imagem selecionada. 
    Retorna:
    lista com médias, lista com desvios padrão
    """
    
    lista = []
    for _ in range(N):
        img_recortada = recortar_quadrado(imagem, tamanho)
        valor = metrica(img_recortada)
        lista.append(valor)
    return np.mean(lista), np.std(lista)

# %%
def temp(funcao):
    return

# %%
def recortar_quadrado_inverso(imagem, tamanho):
    """
    Retorna um recorte da imagem de tamanho tamanho....
    Pedaço aleatório da imagem.

    Parameters
    ----------
    imagem : imagem em formato array
        imagem em formato array
    tamanho : int, optional
        Tamanho de um quadrado.

    Returns
    -------
    recorte : imagem em formato array
        retorna um pedaço da imagem original.

    """
    
    # Seja uma imagem de tamanho x,y
    x,y = imagem.shape
    
    # Quero retirar N pixels das bordas
    # Olhando para somente o eixo x, ele deve ter um tamanho x-pixels
    # Então devo escolher o primeiro valor entre 0 e pixels
    # e o último valor (x- pixels) + pixels
    
    # Intervalo no qual eu posso pegar os pontos
    intervalox = tamanho
    intervaloy = tamanho

    pontox = np.random.randint(0, intervalox)
    pontoy = np.random.randint(0, intervaloy)

    retangulo = [pontox, pontoy, pontox + x-tamanho, pontoy + y - tamanho]
    recorte = imagem[retangulo[0]:retangulo[2], retangulo[1]:retangulo[3]]

    return recorte

# %%
arquivos_na_pasta[0]
# Out:
# 'recorte_leite_00.jpg'

# %% [markdown]
# ## Tarefa, aplicar HS em vários tamanhos diferentes e descobrir qual a diferença entre os valores

# %%
tamanhos = [5,10,50,100,200,500,1000]
iteracoes = [1,10,100,1000]
# tamanhos = [1,5,10]
# iteracoes = [1,10]

# %%
import time
temp = []
primeira_imagem = cv2.imread(arquivos_na_pasta[0],0)
for tamanho in tamanhos:
    for N in iteracoes:
        tic = time.time()
        valor, std = quadrados_media_std(primeira_imagem,N,tamanho,HS)
        temp.append([tamanho,N,valor,std])
        toc = time.time()
        print(tamanho,N,"\nTempo de execução: ",toc-tic)
print(temp)
# Out:
# 5 1
# Tempo de execução:  0.0019989013671875
# 5 10
# Tempo de execução:  0.015991687774658203
# 5 100
# Tempo de execução:  0.10793876647949219
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in longlong_scalars
# 5 1000
# Tempo de execução:  0.8834946155548096
# 10 1
# Tempo de execução:  0.0019974708557128906
# 10 10
# Tempo de execução:  0.018988847732543945
# 10 100
# Tempo de execução:  0.09494519233703613
# 10 1000
# Tempo de execução:  0.8804931640625
# 50 1
# Tempo de execução:  0.0009949207305908203
# 50 10
# Tempo de execução:  0.009987831115722656
# 50 100
# Tempo de execução:  0.09394669532775879
# 50 1000
# Tempo de execução:  1.0503954887390137
# 100 1
# Tempo de execução:  0.0009982585906982422
# 100 10
# Tempo de execução:  0.009996414184570312
# 100 100
# Tempo de execução:  0.09896159172058105
# 100 1000
# Tempo de execução:  1.1043646335601807
# 200 1
# Tempo de execução:  0.001998424530029297
# 200 10
# Tempo de execução:  0.016989946365356445
# 200 100
# Tempo de execução:  0.24186182022094727
# 200 1000
# Tempo de execução:  1.9059083461761475
# 500 1
# Tempo de execução:  0.009012937545776367
# 500 10
# Tempo de execução:  0.09094691276550293
# 500 100
# Tempo de execução:  0.8605072498321533
# 500 1000
# Tempo de execução:  8.442152500152588
# 1000 1
# Tempo de execução:  0.034981489181518555
# 1000 10
# Tempo de execução:  0.431751012802124
# 1000 100
# Tempo de execução:  3.365070104598999
# 1000 1000
# Tempo de execução:  30.813306093215942
# [[5, 1, 0.2857142857142857, 0.0], [5, 10, 0.3252769030998685, 0.13227918032881605], [5, 100, 2.458480182487538, 20.35681976826886], [5, 1000, inf, nan], [10, 1, 0.16666666666666666, 0.0], [10, 10, 0.23161269776691604, 0.10980431311199419], [10, 100, 0.278954454912882, 0.13382266158740277], [10, 1000, 0.2824970095358076, 0.1419980936636857], [50, 1, 0.4819277108433735, 0.0], [50, 10, 0.29847444132408274, 0.18515008195215804], [50, 100, 0.22937029879199247, 0.19207456192796996], [50, 1000, 0.23467599493401667, 0.18511460752112593], [100, 1, 0.028925619834710745, 0.0], [100, 10, 0.24397506379932543, 0.16235804746501736], [100, 100, 0.18696652189283605, 0.17324985265808598], [100, 1000, 0.18749607939558433, 0.1752053288046912], [200, 1, 0.02880658436213992, 0.0], [200, 10, 0.12837865127440776, 0.11204068860283531], [200, 100, 0.15645548243906585, 0.10881864956431442], [200, 1000, 0.17215635119990624, 0.13079638865492288], [500, 1, 0.21176470588235294, 0.0], [500, 10, 0.2015686274509804, 0.07186642314638625], [500, 100, 0.17961479079820905, 0.0662723198870702], [500, 1000, 0.19408950131233596, 0.06286915678059328], [1000, 1, 0.21568627450980393, 0.0], [1000, 10, 0.21607843137254906, 0.011154088355551293], [1000, 100, 0.21713725490196079, 0.021965370669545257], [1000, 1000, 0.21258431372549022, 0.01799966636454436]]

# %%
df2 = pd.DataFrame(data=temp,columns=['Tamanho',"Iteracoes", "Valor", "Std"])
df2
# Out:
#     Tamanho  Iteracoes     Valor        Std
# 0         5          1  0.285714   0.000000
# 1         5         10  0.325277   0.132279
# 2         5        100  2.458480  20.356820
# 3         5       1000       inf        NaN
# 4        10          1  0.166667   0.000000
# 5        10         10  0.231613   0.109804
# 6        10        100  0.278954   0.133823
# 7        10       1000  0.282497   0.141998
# 8        50          1  0.481928   0.000000
# 9        50         10  0.298474   0.185150
# 10       50        100  0.229370   0.192075
# 11       50       1000  0.234676   0.185115
# 12      100          1  0.028926   0.000000
# 13      100         10  0.243975   0.162358
# 14      100        100  0.186967   0.173250
# 15      100       1000  0.187496   0.175205
# 16      200          1  0.028807   0.000000
# 17      200         10  0.128379   0.112041
# 18      200        100  0.156455   0.108819
# 19      200       1000  0.172156   0.130796
# 20      500          1  0.211765   0.000000
# 21      500         10  0.201569   0.071866
# 22      500        100  0.179615   0.066272
# 23      500       1000  0.194090   0.062869
# 24     1000          1  0.215686   0.000000
# 25     1000         10  0.216078   0.011154
# 26     1000        100  0.217137   0.021965
# 27     1000       1000  0.212584   0.018000

# %%
HS(primeira_imagem)
# Out:
# 0.23137254901960785

# %%
sns.relplot(x="Tamanho", y="Valor", data=df2,palette='inferno');

# %%
sns.catplot(x="Tamanho", y="Valor",hue='Iteracoes' ,data=df2.loc[df2.Valor < 1],
            s=10,
            alpha=0.7);
plt.title('HS com vários tamanhos de quadrados e de iterações')
# Out:
# Text(0.5, 1, 'HS com vários tamanhos de quadrados e de iterações')

# %%
sns.catplot(x="Tamanho", y="Valor",col='Iteracoes' ,data=df2.loc[df2.Valor < 1],
           col_wrap=2,
           s=10)

# %%
import time
temp = []
primeira_imagem = cv2.imread(arquivos_na_pasta[0],0)
for tamanho in tamanhos:
    for N in [10000,50000]:
        tic = time.time()
        valor, std = quadrados_media_std(primeira_imagem,N,tamanho,HS)
        temp.append([tamanho,N,valor,std])
        toc = time.time()
        print(tamanho,N,"\nTempo de execução: ",toc-tic)
print(temp)
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in longlong_scalars
# C:\Users\Usuario\Anaconda3\lib\site-packages\numpy\core\_methods.py:117: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# 5 10000
# Tempo de execução:  9.490550518035889
# 5 50000
# Tempo de execução:  48.67206335067749
# 10 10000
# Tempo de execução:  8.886896848678589
# 10 50000
# Tempo de execução:  53.00556540489197
# 50 10000
# Tempo de execução:  13.142455101013184
# 50 50000
# Tempo de execução:  61.77304172515869
# 100 10000
# Tempo de execução:  14.492841720581055
# 100 50000
# Tempo de execução:  60.66216969490051
# 200 10000
# Tempo de execução:  22.580036401748657
# 200 50000
# Tempo de execução:  109.14533185958862
# 500 10000
# Tempo de execução:  102.97287654876709
# 500 50000
# Tempo de execução:  445.6491286754608
# 1000 10000
# Tempo de execução:  309.47632670402527
# 1000 50000
# Tempo de execução:  1747.792760848999
# [[5, 10000, inf, nan], [5, 50000, inf, nan], [10, 10000, 0.3780309171941133, 2.979373256337895], [10, 50000, inf, nan], [50, 10000, 0.23893017298719818, 0.18693383239868747], [50, 50000, 0.23556585305777303, 0.18654741363289085], [100, 10000, 0.19041901402012182, 0.17654730340531913], [100, 50000, 0.19171756336920634, 0.1767354207423829], [200, 10000, 0.1710516673010169, 0.12852040931839526], [200, 50000, 0.16901054459982312, 0.12796186406651375], [500, 10000, 0.19195491122433225, 0.062381839979401124], [500, 50000, 0.19007498131851167, 0.06184644512824433], [1000, 10000, 0.21331647058823533, 0.01892168912285112], [1000, 50000, 0.21302549019607847, 0.01849117446936348]]

# %%
df3 = pd.DataFrame(data=temp,columns=['Tamanho',"Iteracoes", "Valor", "Std"])
df3
# Out:
#     Tamanho  Iteracoes     Valor       Std
# 0         5      10000       inf       NaN
# 1         5      50000       inf       NaN
# 2        10      10000  0.378031  2.979373
# 3        10      50000       inf       NaN
# 4        50      10000  0.238930  0.186934
# 5        50      50000  0.235566  0.186547
# 6       100      10000  0.190419  0.176547
# 7       100      50000  0.191718  0.176735
# 8       200      10000  0.171052  0.128520
# 9       200      50000  0.169011  0.127962
# 10      500      10000  0.191955  0.062382
# 11      500      50000  0.190075  0.061846
# 12     1000      10000  0.213316  0.018922
# 13     1000      50000  0.213025  0.018491

# %%
sns.catplot(x="Tamanho", y="Valor",hue='Iteracoes' ,data=df3.loc[df3.Valor < 1],
            s=10,
            alpha=0.7);

plt.title('HS com vários tamanhos de quadrados e de iterações')
# Out:
# Text(0.5, 1, 'HS com vários tamanhos de quadrados e de iterações')

# %%
df
# Out:
#    Concentracao      Leite        HS       RMS  Michelson
# 0             0  252.34800  0.231373  0.227095   1.000000
# 1             5  250.55025  0.210526  0.082456   2.444444
# 2            10  247.86000  0.200000  0.042151   0.851852
# 3            15  242.00775  0.200000  0.024688   0.440000
# 4            20  234.90600  0.161290  0.015062   0.272727
# 5            25  233.18475  0.172414  0.014121   0.233333
# 6            30  229.83150  0.172414  0.013638   0.235772
# 7            35  228.62025  0.147059  0.015040   0.274194
# 8            99  243.58875  0.185185  0.026970   0.381295

# %% [markdown]
# # Cálculo dos desvios padrão / erros padrão para as métricas

# %% [markdown]
# Passos:
# * Rodar novamente as métricas, utilizando um valor de N = 10.000 iterações.
# * Salvar dados no dataframe.
# * Calcular os erros padrão, coloque também no dataframe.
# * Plotar os gráficos com os erros padrão.
# * Salvar df no pickle, excel.
# * Limpar código, salvar em py

# %%
df_copia = df.copy()

# %%
# 1. Rodar novamente as métricas, utilizando um valor de N = 10.000 iterações.
import time
tamanho = 100
iteracoes = 1000
N = iteracoes
temp = []

primeira_imagem = cv2.imread(arquivos_na_pasta[0],0)

for metrica in [HS, michelson, RMS]:
    for file in arquivos_na_pasta:
        tic = time.time()
        valor, std  = quadrados_media_std(file,N,tamanho,metrica)
        toc = time.time()

    # 2. Salvar dados no dataframe.
    df_temp[metrica.__name__ + '_valor'] = valor
    df_temp[metrica.__name__ + '_std']   = std

    # 3. Calcular os erros padrão, coloque também no dataframe.
    df_temp[metrica.__name__ + '_erro']  = std/100 #std / sqrt(10.000)



print(tamanho,N,"\nTempo de execução: ",toc-tic)
print(temp)
# Out:
# 100 1000
# Tempo de execução:  2.62630295753479
# []

# %%
df_temp[HS.__name__ + '_valor'] = 10

# %%
str()
